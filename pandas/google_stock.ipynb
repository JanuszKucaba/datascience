# %%
import pandas as pd
import pandas_datareader.data as web
import plotly.express as px

pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df = web.DataReader(name='GOOGL', data_source='stooq')
df
# Out:
#               Open    High     Low   Close   Volume
# Date
# 2022-06-10 2248.90 2265.58 2207.32 2223.23  2074092
# 2022-06-09 2326.55 2365.98 2295.52 2296.71  1289898
# 2022-06-08 2335.23 2371.41 2332.00 2343.88  1305387
# 2022-06-07 2309.61 2353.82 2301.04 2342.99  1579523
# 2022-06-06 2334.09 2386.94 2323.28 2336.41  1677077
# ...            ...     ...     ...     ...      ...
# 2017-06-20  975.31  980.79  968.20  968.99  1297019
# 2017-06-19  969.65  979.30  968.20  975.22  1466053
# 2017-06-16  957.91  959.95  948.70  958.62  2545952
# 2017-06-15  948.02  960.68  940.37  960.18  2369353
# 2017-06-14  975.50  979.70  959.51  967.93  1499807
#
# [1258 rows x 5 columns]

# %%
df.describe()
# Out:
#          Open    High     Low   Close     Volume
# count 1258.00 1258.00 1258.00 1258.00    1258.00
# mean  1593.70 1610.11 1576.79 1593.87 1768543.10
# std    636.26  642.21  628.66  635.27  814125.66
# min    919.95  928.25  915.31  919.46  465638.00
# 25%   1112.33 1122.97 1099.75 1111.41 1259321.25
# 50%   1270.80 1280.34 1258.86 1271.71 1557184.00
# 75%   2065.89 2098.79 2047.75 2083.41 2008750.25
# max   3025.00 3030.93 2977.98 2996.77 6658855.00

# %%
df = df.reset_index()
df.head()
# Out:
#         Date    Open    High     Low   Close   Volume
# 0 2022-06-10 2248.90 2265.58 2207.32 2223.23  2074092
# 1 2022-06-09 2326.55 2365.98 2295.52 2296.71  1289898
# 2 2022-06-08 2335.23 2371.41 2332.00 2343.88  1305387
# 3 2022-06-07 2309.61 2353.82 2301.04 2342.99  1579523
# 4 2022-06-06 2334.09 2386.94 2323.28 2336.41  1677077

# %%
df.tail()
# Out:
#            Date   Open   High    Low  Close   Volume
# 1253 2017-06-20 975.31 980.79 968.20 968.99  1297019
# 1254 2017-06-19 969.65 979.30 968.20 975.22  1466053
# 1255 2017-06-16 957.91 959.95 948.70 958.62  2545952
# 1256 2017-06-15 948.02 960.68 940.37 960.18  2369353
# 1257 2017-06-14 975.50 979.70 959.51 967.93  1499807

# %%
df_2019 = df.query("Date > '2019-01-01'")
df_2019
# Out:
#           Date    Open    High     Low   Close   Volume
# 0   2022-06-10 2248.90 2265.58 2207.32 2223.23  2074092
# 1   2022-06-09 2326.55 2365.98 2295.52 2296.71  1289898
# 2   2022-06-08 2335.23 2371.41 2332.00 2343.88  1305387
# 3   2022-06-07 2309.61 2353.82 2301.04 2342.99  1579523
# 4   2022-06-06 2334.09 2386.94 2323.28 2336.41  1677077
# ..         ...     ...     ...     ...     ...      ...
# 863 2019-01-08 1086.00 1093.35 1068.35 1085.37  1770654
# 864 2019-01-07 1080.97 1082.70 1062.64 1075.92  2372667
# 865 2019-01-04 1042.56 1080.00 1036.86 1078.07  2301428
# 866 2019-01-03 1050.67 1066.26 1022.37 1025.47  2097957
# 867 2019-01-02 1027.20 1060.79 1025.28 1054.68  1593395
#
# [868 rows x 6 columns]

# %%
px.line(df_2019, x='Date', y='Close', title='Stock quotes of the google company (GOOGL)',
        width=900, height=500, log_y=True, color_discrete_sequence=['#03fcc2'],
        template='plotly_dark')

# %%
px.area(df_2019, x='Date', y='Close', title='Stock quotes of the google company (GOOGL)',
        width=900, height=500, log_y=True, color_discrete_sequence=['#c50ff7'],
        template='plotly_dark')
